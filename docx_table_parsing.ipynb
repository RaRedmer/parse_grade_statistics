# %%
import pandas as pd
from docx.api import Document
import pandas as pd
import re
import os
import numpy as np
import tabula

# %%
def extract_mapping(file_name):
    graduate_list = tabula.read_pdf(f"pdfs/{file_name}.pdf", pages=[1,2,3,4,5,6], multiple_tables=True, relative_area=True)

    exam_number_mapping = {}
    for table in graduate_list:
        if len(table.columns) == 3:  # in case of viable mapping table
            if list(table[1][table[1].str.contains('B. Sc.|Bachelor') == True]):
                extract_df = table.dropna()[[0,1]]
                exam_number_mapping['Bachelor'] = {row[0].replace(' ',''): row[1]  for row in extract_df.to_dict('records')}
            elif list(table[1][table[1].str.contains('M. Sc.|Master') == True]):
                extract_df = table.dropna()[[0,1]]
                exam_number_mapping['Master'] = {row[0].replace(' ',''): row[1]  for row in extract_df.to_dict('records')}

        elif len(table.columns) == 4:
            if list(table[1][table[1].str.contains('B. Sc.|Bachelor') == True]):
                extract_df = table[[0,1]].dropna()
                exam_number_mapping['Bachelor'] = {row[0].replace(' ',''): row[1]  for row in extract_df.to_dict('records')}
            elif list(table[1][table[1].str.contains('M. Sc.|Master') == True]):
                extract_df = table[[0,1]].dropna()
                exam_number_mapping['Master'] = {row[0].replace(' ',''): row[1]  for row in extract_df.to_dict('records')}                
                
        elif len(table.columns) == 5:
            if list(table[2][table[2].str.contains('B. Sc.|Bachelor') == True]):
                extract_df = table[[0,2]].dropna()
                exam_number_mapping['Bachelor'] = {row[0].replace(' ',''): row[2]  for row in extract_df.to_dict('records')}
            elif list(table[2][table[2].str.contains('M. Sc.|Master') == True]):
                extract_df = table[[0,2]].dropna()
                exam_number_mapping['Master'] = {row[0].replace(' ',''): row[2]  for row in extract_df.to_dict('records')}
                       
    return exam_number_mapping

# %%
path = 'word_docs'
total_mapping = {}
file_names = os.listdir(path)
total_graduate_data = pd.DataFrame()
na_counter = 0
for file_name in reversed(file_names):
    print(file_name)
    document = Document(f'word_docs/{file_name}')
    exam_year = re.search(r'(\d+)', file_name).group(1)
    exam_semester = re.search(r'^(.+)_\d+\.docx', file_name).group(1)
    
    word_table = document.tables
    mapping = extract_mapping(file_name=re.search(r'(.+)\.docx', file_name).group(1))
    total_mapping.update(mapping)  # add new Prüfungsnummer
    table_count = 0
    for table in word_table:
        # convert to pandas
        table_list = [[cell.text for cell in row.cells] for row in table.rows]
        table_df = pd.DataFrame(table_list)
        if len(table_df.columns) == 11:  # in case of viable grade-table
            # extract exam number from table
            try:
                exam_number = re.search(r'(\d+)', table_df[0][0]).group(1)
            except:
                exam_number = np.nan
                na_counter += 1
            # restrict to only those rows that contain grades
            table_df = table_df[table_df[1].str.contains(r'\d,\d')][[1, 2, 5, 8]]
            table_df.columns = ['Grade', 'first_exam', 'second_exam', 'total']  # rename

            table_df['exam_year'] = exam_year
            table_df['exam_semester'] = exam_semester
            table_df['exam_number'] = exam_number
            # map course onto exam_number
            try:
                table_df['course'] = total_mapping['Bachelor'][exam_number]
                table_df['degree'] = 'Bachelor'
            except:
                try:
                    table_df['course'] = total_mapping['Master'][exam_number]
                    table_df['degree'] = 'Master'
                except:
                    table_df['course'] = np.nan
                    table_df['degree'] = np.nan
            table_count += 1
            total_graduate_data = pd.concat([total_graduate_data, table_df])
    print(f'Number of tables: {table_count}')

print(f'Non-available Prüfungsnummer: {na_counter}')
# Out:
# Wintersemester_2017.docx
# Number of tables: 44
# Wintersemester_2016.docx
# Number of tables: 46
# Wintersemester_2015.docx
# Number of tables: 40
# Wintersemester_2014.docx
# Number of tables: 41
# Wintersemester_2013.docx
# Number of tables: 40
# Wintersemester_2012.docx
# Number of tables: 39
# Sommersemester_2018.docx
# Number of tables: 43
# Sommersemester_2017.docx
# Number of tables: 40
# Sommersemester_2016.docx
# Number of tables: 40
# Sommersemester_2015.docx
# Number of tables: 40
# Sommersemester_2014.docx
# Number of tables: 40
# Sommersemester_2013.docx
# Number of tables: 39
# Non-available Prüfungsnummer: 1

# %%
total_graduate_data[total_graduate_data['first_exam'].str.contains('^\n', regex=True)==True]
# Out:
#    Grade                                         first_exam  \
# 3    1,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 4    1,3  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 5    1,7  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 6    2,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 7    2,3  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 8    2,7  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 9    3,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 10   3,3  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 11   3,7  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 12   4,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 13   5,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 3    1,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 4    1,3  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 5    1,7  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 6    2,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 7    2,3  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 8    2,7  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 9    3,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 10   3,3  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 11   3,7  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 12   4,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 13   5,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 3    1,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 4    1,3  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 5    1,7  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 6    2,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 7    2,3  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 8    2,7  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 9    3,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 10   3,3  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# ..   ...                                                ...
# 6    2,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 7    2,3  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 8    2,7  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 9    3,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 10   3,3  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 11   3,7  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 12   4,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 13   5,0  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...
# 3    1,0  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 4    1,3  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 5    1,7  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 6    2,0  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 7    2,3  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 8    2,7  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 9    3,0  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 10   3,3  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 11   3,7  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 12   4,0  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 13   5,0  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 3    1,0  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 4    1,3  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 5    1,7  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 6    2,0  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 7    2,3  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 8    2,7  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 9    3,0  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 10   3,3  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 11   3,7  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 12   4,0  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
# 13   5,0  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...
#
#                                           second_exam total exam_year  \
# 3   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     3      2017
# 4   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     4      2017
# 5   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     2      2017
# 6   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     1      2017
# 7   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     1      2017
# 8   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     2      2017
# 9   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2017
# 10  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2017
# 11  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2017
# 12  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2017
# 13  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     2      2017
# 3   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     2      2017
# 4   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     1      2017
# 5   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     1      2017
# 6   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     1      2017
# 7   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2017
# 8   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2017
# 9   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2017
# 10  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     1      2017
# 11  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2017
# 12  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2017
# 13  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     1      2017
# 3   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     4      2017
# 4   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     2      2017
# 5   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     1      2017
# 6   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2017
# 7   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     3      2017
# 8   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2017
# 9   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     1      2017
# 10  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     1      2017
# ..                                                ...   ...       ...
# 6   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     3      2014
# 7   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     5      2014
# 8   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2014
# 9   \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2014
# 10  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2014
# 11  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2014
# 12  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2014
# 13  \n\n\n\n\n\n\n\nAus datenschutzrechtlichen Grü...     0      2014
# 3   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     4      2014
# 4   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     2      2014
# 5   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     1      2014
# 6   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     3      2014
# 7   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     2      2014
# 8   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     0      2014
# 9   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     0      2014
# 10  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     0      2014
# 11  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     0      2014
# 12  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     2      2014
# 13  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     5      2014
# 3   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     1      2014
# 4   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     1      2014
# 5   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     2      2014
# 6   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     3      2014
# 7   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     2      2014
# 8   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     2      2014
# 9   \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     0      2014
# 10  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     0      2014
# 11  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     0      2014
# 12  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     0      2014
# 13  \n\n\n\n\n\n\n\n\nAus datenschutzrechtlichen G...     2      2014
#
#      exam_semester exam_number                                 course  degree
# 3   Wintersemester   332224027                      Corporate Finance  Master
# 4   Wintersemester   332224027                      Corporate Finance  Master
# 5   Wintersemester   332224027                      Corporate Finance  Master
# 6   Wintersemester   332224027                      Corporate Finance  Master
# 7   Wintersemester   332224027                      Corporate Finance  Master
# 8   Wintersemester   332224027                      Corporate Finance  Master
# 9   Wintersemester   332224027                      Corporate Finance  Master
# 10  Wintersemester   332224027                      Corporate Finance  Master
# 11  Wintersemester   332224027                      Corporate Finance  Master
# 12  Wintersemester   332224027                      Corporate Finance  Master
# 13  Wintersemester   332224027                      Corporate Finance  Master
# 3   Wintersemester   332225028                     Econometric Theory  Master
# 4   Wintersemester   332225028                     Econometric Theory  Master
# 5   Wintersemester   332225028                     Econometric Theory  Master
# 6   Wintersemester   332225028                     Econometric Theory  Master
# 7   Wintersemester   332225028                     Econometric Theory  Master
# 8   Wintersemester   332225028                     Econometric Theory  Master
# 9   Wintersemester   332225028                     Econometric Theory  Master
# 10  Wintersemester   332225028                     Econometric Theory  Master
# 11  Wintersemester   332225028                     Econometric Theory  Master
# 12  Wintersemester   332225028                     Econometric Theory  Master
# 13  Wintersemester   332225028                     Econometric Theory  Master
# 3   Wintersemester   332223022               Economics and Psychology  Master
# 4   Wintersemester   332223022               Economics and Psychology  Master
# 5   Wintersemester   332223022               Economics and Psychology  Master
# 6   Wintersemester   332223022               Economics and Psychology  Master
# 7   Wintersemester   332223022               Economics and Psychology  Master
# 8   Wintersemester   332223022               Economics and Psychology  Master
# 9   Wintersemester   332223022               Economics and Psychology  Master
# 10  Wintersemester   332223022               Economics and Psychology  Master
# ..             ...         ...                                    ...     ...
# 6   Sommersemester   332225027                      Microeconometrics  Master
# 7   Sommersemester   332225027                      Microeconometrics  Master
# 8   Sommersemester   332225027                      Microeconometrics  Master
# 9   Sommersemester   332225027                      Microeconometrics  Master
# 10  Sommersemester   332225027                      Microeconometrics  Master
# 11  Sommersemester   332225027                      Microeconometrics  Master
# 12  Sommersemester   332225027                      Microeconometrics  Master
# 13  Sommersemester   332225027                      Microeconometrics  Master
# 3   Sommersemester   332225031               Time Series Econometrics  Master
# 4   Sommersemester   332225031               Time Series Econometrics  Master
# 5   Sommersemester   332225031               Time Series Econometrics  Master
# 6   Sommersemester   332225031               Time Series Econometrics  Master
# 7   Sommersemester   332225031               Time Series Econometrics  Master
# 8   Sommersemester   332225031               Time Series Econometrics  Master
# 9   Sommersemester   332225031               Time Series Econometrics  Master
# 10  Sommersemester   332225031               Time Series Econometrics  Master
# 11  Sommersemester   332225031               Time Series Econometrics  Master
# 12  Sommersemester   332225031               Time Series Econometrics  Master
# 13  Sommersemester   332225031               Time Series Econometrics  Master
# 3   Sommersemester   332225036  Econometrics II: Statistical Analysis  Master
# 4   Sommersemester   332225036  Econometrics II: Statistical Analysis  Master
# 5   Sommersemester   332225036  Econometrics II: Statistical Analysis  Master
# 6   Sommersemester   332225036  Econometrics II: Statistical Analysis  Master
# 7   Sommersemester   332225036  Econometrics II: Statistical Analysis  Master
# 8   Sommersemester   332225036  Econometrics II: Statistical Analysis  Master
# 9   Sommersemester   332225036  Econometrics II: Statistical Analysis  Master
# 10  Sommersemester   332225036  Econometrics II: Statistical Analysis  Master
# 11  Sommersemester   332225036  Econometrics II: Statistical Analysis  Master
# 12  Sommersemester   332225036  Econometrics II: Statistical Analysis  Master
# 13  Sommersemester   332225036  Econometrics II: Statistical Analysis  Master
#
# [715 rows x 9 columns]

# %%
# clean data
total_graduate_data['first_exam'][total_graduate_data['first_exam'].str.contains('^\n', regex=True)==True] = np.nan
total_graduate_data['second_exam'][total_graduate_data['second_exam'].str.contains('^\n', regex=True)==True] = np.nan
total_graduate_data['total'][total_graduate_data['total'].str.contains('^\n', regex=True)==True] = np.nan
# convert to numeric
total_graduate_data[["first_exam", "second_exam", "total"]] = total_graduate_data[["first_exam", "second_exam", "total"]].apply(pd.to_numeric)

# %%
total_graduate_data[total_graduate_data['total'].isnull()]
# Out:
#    Grade  first_exam  second_exam  total exam_year   exam_semester  \
# 3    1,0        18.0          NaN    NaN      2017  Wintersemester
# 4    1,3        15.0          NaN    NaN      2017  Wintersemester
# 5    1,7        21.0          NaN    NaN      2017  Wintersemester
# 6    2,0         9.0          NaN    NaN      2017  Wintersemester
# 7    2,3         4.0          NaN    NaN      2017  Wintersemester
# 8    2,7         3.0          NaN    NaN      2017  Wintersemester
# 9    3,0         0.0          NaN    NaN      2017  Wintersemester
# 10   3,3         0.0          NaN    NaN      2017  Wintersemester
# 11   3,7         0.0          NaN    NaN      2017  Wintersemester
# 12   4,0         0.0          NaN    NaN      2017  Wintersemester
# 13   5,0         3.0          NaN    NaN      2017  Wintersemester
# 3    1,0         0.0          NaN    NaN      2017  Wintersemester
# 4    1,3        10.0          NaN    NaN      2017  Wintersemester
# 5    1,7         4.0          NaN    NaN      2017  Wintersemester
# 6    2,0         0.0          NaN    NaN      2017  Wintersemester
# 7    2,3         0.0          NaN    NaN      2017  Wintersemester
# 8    2,7         0.0          NaN    NaN      2017  Wintersemester
# 9    3,0         0.0          NaN    NaN      2017  Wintersemester
# 10   3,3         0.0          NaN    NaN      2017  Wintersemester
# 11   3,7         0.0          NaN    NaN      2017  Wintersemester
# 12   4,0         0.0          NaN    NaN      2017  Wintersemester
# 13   5,0         0.0          NaN    NaN      2017  Wintersemester
# 3    1,0         6.0          NaN    NaN      2017  Wintersemester
# 4    1,3         3.0          NaN    NaN      2017  Wintersemester
# 5    1,7         0.0          NaN    NaN      2017  Wintersemester
# 6    2,0         0.0          NaN    NaN      2017  Wintersemester
# 7    2,3         4.0          NaN    NaN      2017  Wintersemester
# 8    2,7         0.0          NaN    NaN      2017  Wintersemester
# 9    3,0         0.0          NaN    NaN      2017  Wintersemester
# 10   3,3         0.0          NaN    NaN      2017  Wintersemester
# ..   ...         ...          ...    ...       ...             ...
# 6    2,0         1.0          NaN    NaN      2016  Sommersemester
# 7    2,3         0.0          NaN    NaN      2016  Sommersemester
# 8    2,7         0.0          NaN    NaN      2016  Sommersemester
# 9    3,0         1.0          NaN    NaN      2016  Sommersemester
# 10   3,3         0.0          NaN    NaN      2016  Sommersemester
# 11   3,7         0.0          NaN    NaN      2016  Sommersemester
# 12   4,0         0.0          NaN    NaN      2016  Sommersemester
# 13   5,0         0.0          NaN    NaN      2016  Sommersemester
# 3    1,0         0.0          NaN    NaN      2016  Sommersemester
# 4    1,3         0.0          NaN    NaN      2016  Sommersemester
# 5    1,7         3.0          NaN    NaN      2016  Sommersemester
# 6    2,0         0.0          NaN    NaN      2016  Sommersemester
# 7    2,3         0.0          NaN    NaN      2016  Sommersemester
# 8    2,7         0.0          NaN    NaN      2016  Sommersemester
# 9    3,0         0.0          NaN    NaN      2016  Sommersemester
# 10   3,3         1.0          NaN    NaN      2016  Sommersemester
# 11   3,7         1.0          NaN    NaN      2016  Sommersemester
# 12   4,0         0.0          NaN    NaN      2016  Sommersemester
# 13   5,0         0.0          NaN    NaN      2016  Sommersemester
# 3    1,0         0.0          NaN    NaN      2016  Sommersemester
# 4    1,3         6.0          NaN    NaN      2016  Sommersemester
# 5    1,7        10.0          NaN    NaN      2016  Sommersemester
# 6    2,0         4.0          NaN    NaN      2016  Sommersemester
# 7    2,3         1.0          NaN    NaN      2016  Sommersemester
# 8    2,7         0.0          NaN    NaN      2016  Sommersemester
# 9    3,0         0.0          NaN    NaN      2016  Sommersemester
# 10   3,3         0.0          NaN    NaN      2016  Sommersemester
# 11   3,7         0.0          NaN    NaN      2016  Sommersemester
# 12   4,0         0.0          NaN    NaN      2016  Sommersemester
# 13   5,0         0.0          NaN    NaN      2016  Sommersemester
#
#    exam_number                                           course    degree
# 3    333210050                      Wissenschaftliches Arbeiten  Bachelor
# 4    333210050                      Wissenschaftliches Arbeiten  Bachelor
# 5    333210050                      Wissenschaftliches Arbeiten  Bachelor
# 6    333210050                      Wissenschaftliches Arbeiten  Bachelor
# 7    333210050                      Wissenschaftliches Arbeiten  Bachelor
# 8    333210050                      Wissenschaftliches Arbeiten  Bachelor
# 9    333210050                      Wissenschaftliches Arbeiten  Bachelor
# 10   333210050                      Wissenschaftliches Arbeiten  Bachelor
# 11   333210050                      Wissenschaftliches Arbeiten  Bachelor
# 12   333210050                      Wissenschaftliches Arbeiten  Bachelor
# 13   333210050                      Wissenschaftliches Arbeiten  Bachelor
# 3    332223026   Effective Programming Practices for Economists    Master
# 4    332223026   Effective Programming Practices for Economists    Master
# 5    332223026   Effective Programming Practices for Economists    Master
# 6    332223026   Effective Programming Practices for Economists    Master
# 7    332223026   Effective Programming Practices for Economists    Master
# 8    332223026   Effective Programming Practices for Economists    Master
# 9    332223026   Effective Programming Practices for Economists    Master
# 10   332223026   Effective Programming Practices for Economists    Master
# 11   332223026   Effective Programming Practices for Economists    Master
# 12   332223026   Effective Programming Practices for Economists    Master
# 13   332223026   Effective Programming Practices for Economists    Master
# 3    332225050  Research Module in Economectrics and Statistics    Master
# 4    332225050  Research Module in Economectrics and Statistics    Master
# 5    332225050  Research Module in Economectrics and Statistics    Master
# 6    332225050  Research Module in Economectrics and Statistics    Master
# 7    332225050  Research Module in Economectrics and Statistics    Master
# 8    332225050  Research Module in Economectrics and Statistics    Master
# 9    332225050  Research Module in Economectrics and Statistics    Master
# 10   332225050  Research Module in Economectrics and Statistics    Master
# ..         ...                                              ...       ...
# 6    332222007                           Dynamic Macroeconomics    Master
# 7    332222007                           Dynamic Macroeconomics    Master
# 8    332222007                           Dynamic Macroeconomics    Master
# 9    332222007                           Dynamic Macroeconomics    Master
# 10   332222007                           Dynamic Macroeconomics    Master
# 11   332222007                           Dynamic Macroeconomics    Master
# 12   332222007                           Dynamic Macroeconomics    Master
# 13   332222007                           Dynamic Macroeconomics    Master
# 3    332221010                                Microeconomics II    Master
# 4    332221010                                Microeconomics II    Master
# 5    332221010                                Microeconomics II    Master
# 6    332221010                                Microeconomics II    Master
# 7    332221010                                Microeconomics II    Master
# 8    332221010                                Microeconomics II    Master
# 9    332221010                                Microeconomics II    Master
# 10   332221010                                Microeconomics II    Master
# 11   332221010                                Microeconomics II    Master
# 12   332221010                                Microeconomics II    Master
# 13   332221010                                Microeconomics II    Master
# 3          NaN                                              NaN       NaN
# 4          NaN                                              NaN       NaN
# 5          NaN                                              NaN       NaN
# 6          NaN                                              NaN       NaN
# 7          NaN                                              NaN       NaN
# 8          NaN                                              NaN       NaN
# 9          NaN                                              NaN       NaN
# 10         NaN                                              NaN       NaN
# 11         NaN                                              NaN       NaN
# 12         NaN                                              NaN       NaN
# 13         NaN                                              NaN       NaN
#
# [385 rows x 9 columns]

# %%
# make column 'total' s.t. it is always sum of 'first_exam' and 'second_exam'
total_graduate_data['total'] = np.select(
                                            [
                                                total_graduate_data['total'].isnull(), 
                                                ~total_graduate_data['total'].isnull()
                                            ], 
                                            [
                                                total_graduate_data['first_exam'].add(total_graduate_data['second_exam'], fill_value=0), 
                                                total_graduate_data['total']
                                            ], 
                                                total_graduate_data['total']
                                        )

# %%
# no data was available for these courses
total_graduate_data[total_graduate_data['total'].isnull()]
# Out:
#    Grade  first_exam  second_exam  total exam_year   exam_semester  \
# 3    1,0         NaN          NaN    NaN      2018  Sommersemester
# 4    1,3         NaN          NaN    NaN      2018  Sommersemester
# 5    1,7         NaN          NaN    NaN      2018  Sommersemester
# 6    2,0         NaN          NaN    NaN      2018  Sommersemester
# 7    2,3         NaN          NaN    NaN      2018  Sommersemester
# 8    2,7         NaN          NaN    NaN      2018  Sommersemester
# 9    3,0         NaN          NaN    NaN      2018  Sommersemester
# 10   3,3         NaN          NaN    NaN      2018  Sommersemester
# 11   3,7         NaN          NaN    NaN      2018  Sommersemester
# 12   4,0         NaN          NaN    NaN      2018  Sommersemester
# 13   5,0         NaN          NaN    NaN      2018  Sommersemester
# 3    1,0         NaN          NaN    NaN      2018  Sommersemester
# 4    1,3         NaN          NaN    NaN      2018  Sommersemester
# 5    1,7         NaN          NaN    NaN      2018  Sommersemester
# 6    2,0         NaN          NaN    NaN      2018  Sommersemester
# 7    2,3         NaN          NaN    NaN      2018  Sommersemester
# 8    2,7         NaN          NaN    NaN      2018  Sommersemester
# 9    3,0         NaN          NaN    NaN      2018  Sommersemester
# 10   3,3         NaN          NaN    NaN      2018  Sommersemester
# 11   3,7         NaN          NaN    NaN      2018  Sommersemester
# 12   4,0         NaN          NaN    NaN      2018  Sommersemester
# 13   5,0         NaN          NaN    NaN      2018  Sommersemester
#
#    exam_number                                             course    degree
# 3    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 4    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 5    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 6    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 7    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 8    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 9    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 10   333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 11   333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 12   333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 13   333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 3    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 4    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 5    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 6    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 7    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 8    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 9    333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 10   333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 11   333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 12   333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor
# 13   333210002  Grundzüge der VWL: Einführung in die Makroökon...  Bachelor

# %%
total_graduate_data.to_excel('grade_stats.xlsx', index=False)
